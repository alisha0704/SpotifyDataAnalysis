# %% [markdown]
# <a href="https://colab.research.google.com/github/alisha0704/SpotifyDataAnalysis/blob/main/Spotify_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_tracks = pd.read_csv('tracks.csv')
df_tracks.head()
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit              artists                  id_artists  \
# 0       126903         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1        98200         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
# 2       181640         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 3       176907         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 4       163080         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']
#
# ...

# %%
pd.isnull(df_tracks).sum()
# Out:
# id                  0
# name                0
# popularity          0
# duration_ms         0
# explicit            0
# artists             0
# id_artists          0
# release_date        0
# danceability        0
# energy              1
# key                 1
# loudness            1
# mode                1
# speechiness         1
# acousticness        1
# instrumentalness    1
# liveness            1
# valence             1
# tempo               1
# time_signature      1
# dtype: int64

# %%
df_tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106792 entries, 0 to 106791
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                106792 non-null  object
#  1   name              106792 non-null  object
#  2   popularity        106792 non-null  int64
#  3   duration_ms       106792 non-null  int64
#  4   explicit          106792 non-null  int64
#  5   artists           106792 non-null  object
#  6   id_artists        106792 non-null  object
#  7   release_date      106792 non-null  object
#  8   danceability      106792 non-null  float64
#  9   energy            106791 non-null  float64
#  10  key               106791 non-null  float64
#  11  loudness          106791 non-null  float64
#  12  mode              106791 non-null  float64
#  13  speechiness       106791 non-null  float64
#  14  acousticness      106791 non-null  float64
# ...

# %%
sorted_df = df_tracks.sort_values('popularity', ascending=True).head(10)
sorted_df
# Out:
#                             id  \
# 106791  0c3PzTRRDl8piRUCEl3ZYK
# 17433   5wf6BrHvafXM8dRvSjJ1Ft
# 17432   5wIvIXAT917grcmcsALBjF
# 17430   5v44Q2nUNIG1Mbm2dBEzAp
# 17428   5tXssjEkUVFwV5EPeVQCvs
# 17427   5rsSEp6bChmjAiY4NXdayc
# 17426   5qWOmAIsLp3RzlmMOj1drE
# 17425   5q7YfJTub8kArMUGLymxky
# 17423   5opokoSULMCwS9pkJ8Dkw7
# 17421   5oAisaYJegNYvocduELvuF
#
#                                                      name  popularity  \
# 106791                               Future Music - Remix           0
# 17433                        Hark! The Herald Angels Sing           0
# 17432   13 Preludes, Op. 32: No. 13 in D-Flat Major: G...           0
# 17430                   Der var Engang: No. 3, Aftenmusik           0
# 17428                          Phool Ki Patti Sa Tan Iska           0
# 17427               Y No la Puedo Olvidar - Remasterizado           0
# 17426                          Saqi Ki Nigahen Sharab Hai           0
# ...

# %%
df_tracks.describe().transpose()
# Out:
#                      count           mean            std     min          25%  \
# popularity        106792.0      29.700727      23.973112     0.0       4.0000
# duration_ms       106792.0  229994.027755  139117.909454  3344.0  168107.0000
# explicit          106792.0       0.036801       0.188273     0.0       0.0000
# danceability      106792.0       0.541837       0.170265     0.0       0.4250
# energy            106791.0       0.471789       0.266284     0.0       0.2470
# key               106791.0       5.190625       3.504833     0.0       2.0000
# loudness          106791.0     -11.741822       5.492328   -60.0     -14.8175
# mode              106791.0       0.699272       0.458577     0.0       0.0000
# speechiness       106791.0       0.101436       0.179252     0.0       0.0347
# acousticness      106791.0       0.530160       0.374075     0.0       0.1290
# instrumentalness  106791.0       0.181717       0.324025     0.0       0.0000
# ...

# %%
most_popular = df_tracks.query('popularity > 90', inplace=False).sort_values('popularity', ascending=False)
most_popular.head(10)
# Out:
#                            id                                    name  \
# 93802  4iJyoBOLtHqaGxP12qzhQI  Peaches (feat. Daniel Caesar & Giveon)
# 93803  7lPN2DXiMsVn7XUKtOW1CS                         drivers license
# 93804  3Ofmpyhv5UAQ70mENzB277                  Astronaut In The Ocean
# 92810  5QO79kh1waicV47BqGRL3g                         Save Your Tears
# 92811  6tDDoYIxWvMLTdKpjFkc1B                               telepatía
# 92813  0VjIjW4GlUZAMYd2vXMi3b                         Blinding Lights
# 93805  7MAibcTli4IisCtbHKrGMh                     Leave The Door Open
# 92814  6f3Slt0GbA2bPZlz0aIFXN                            The Business
# 91866  60ynsPSSKe6O3sfwRnIBRf                                 Streets
# 92816  3FAJ6O0NOHQV8Mc5Ri6ENp                  Heartbreak Anniversary
#
#        popularity  duration_ms  explicit  \
# 93802         100       198082         1
# 93803          99       242014         1
# 93804          98       132780         0
# ...

# %%
df_tracks.columns
# Out:
# Index(['id', 'name', 'popularity', 'duration_ms', 'explicit', 'artists',
#        'id_artists', 'danceability', 'energy', 'key', 'loudness', 'mode',
#        'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'time_signature'],
#       dtype='object')

# %%
df_tracks.index
# Out:
# Index(['1922-02-22', '1922-06-01', '1922-03-21', '1922-03-21', '1922', '1922',
#        '1922', '1922', '1922', '1922-03-29',
#        ...
#        '1993-01-01', '2013-09-17', '2013-09-17', '2019-06-28', '1993-08-24',
#        '2020-02-07', '1993-09-24', '2020-02-07', '2013-09-17', '2020-02-07'],
#       dtype='object', name='release_date', length=106792)

# %%
df_tracks.reset_index(inplace=True)

# %%
df_tracks.columns
# Out:
# Index(['release_date', 'id', 'name', 'popularity', 'duration_ms', 'explicit',
#        'artists', 'id_artists', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'time_signature'],
#       dtype='object')

# %%
df_tracks.set_index('release_date', inplace=True)
df_tracks.index = pd.to_datetime(df_tracks.index, errors='coerce')
df_tracks.head()
# Out:
#                                   id                                 name  \
# release_date
# 1922-02-22    35iwgR4jXetI318WEWsa1Q                                Carve
# 1922-06-01    021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 1922-03-21    07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 1922-03-21    08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# NaT           08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
#
#               popularity  duration_ms  explicit              artists  \
# release_date
# 1922-02-22             6       126903         0              ['Uli']
# 1922-06-01             0        98200         0  ['Fernando Pessoa']
# 1922-03-21             0       181640         0  ['Ignacio Corsini']
# 1922-03-21             0       176907         0  ['Ignacio Corsini']
# NaT                    0       163080         0      ['Dick Haymes']
#
# ...

# %%
df_tracks[['artists']].iloc[18]
# Out:
# artists    ['Victor Boucher']
# Name: NaT, dtype: object
